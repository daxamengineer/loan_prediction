# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("loan_approval_dataset.csv")
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %% [markdown]
# ### Cleaning the Data

# %%
primary_color = '#026558'

# Calculating the percentage of missing values for each column
missing_data = df.isnull().sum()
missing_percentage = (missing_data[missing_data > 0] / df.shape[0]) * 100

# Prepare values
missing_percentage.sort_values(ascending=True, inplace=True)

# Plot the barh chart
fig, ax = plt.subplots(figsize=(15, 4))
ax.barh(missing_percentage.index, missing_percentage, color=primary_color)

# Annotate the values and indexes
for i, (value, name) in enumerate(zip(missing_percentage, missing_percentage.index)):
    ax.text(value+0.5, i, f"{value:.2f}%", ha='left', va='center', fontweight='bold', fontsize=18, color='black')

# Set x-axis limit
ax.set_xlim([0, 40])

# Add title and xlabel
plt.title("Percentage of Missing Values", fontweight='bold', fontsize=22)
plt.xlabel('Percentages (%)', fontsize=16)
plt.show()

# %% [markdown]
# ##### No missing values.

# %%
# Finding duplicate rows 
duplicate_rows = df[df.duplicated(keep=False)]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [loan_id,  no_of_dependents,  education,  self_employed,  income_annum,  loan_amount,  loan_term,  cibil_score,  residential_assets_value,  commercial_assets_value,  luxury_assets_value,  bank_asset_value,  loan_status]
# Index: []

# %%
#removing whitespaces
new_columns = []
for col in df.columns:
    new_columns.append(col.strip())
df.columns = new_columns

for i in range(df.shape[0]):  
    for j in range(df.shape[1]):  
        if isinstance(df.iat[i, j], str): 
            df.iat[i, j] = df.iat[i, j].strip()

# %%
#scaling loan term between 5 and 15 months
scaler = MinMaxScaler(feature_range=(5, 15))
df['scaled_loan_term'] = scaler.fit_transform(df['loan_term'].values[:, None])

# %% [markdown]
# ##### Dropping duplicates if exists and dropping loan_id and loan_term.

# %%
df.drop_duplicates(inplace=True)
df = df.drop(columns=["loan_id"])
df = df.drop(columns=["loan_term"])
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    cibil_score  residential_assets_value  commercial_assets_value  \
# 0          778                   2400000                 17600000
# 1          417                   2700000                  2200000
# 2          506                   7100000                  4500000
# 3          467                  18200000                  3300000
# 4          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value loan_status  scaled_loan_term
# ...

# %%
df.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status', 'scaled_loan_term'],
#       dtype='object')

# %%
# Replacing values in education, self_employed, loan_status
df["education"] = df["education"].replace("Graduate", 1)
df["education"] = df["education"].replace("Not Graduate", 0)
df["self_employed"] = df["self_employed"].replace("No", 0)
df["self_employed"] = df["self_employed"].replace("Yes", 1)
df["loan_status"] = df["loan_status"].replace("Approved", 1)
df["loan_status"] = df["loan_status"].replace("Rejected", 0)
df.head()
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_15652\1583950878.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["education"] = df["education"].replace("Not Graduate", 0)
# C:\Users\anish\AppData\Local\Temp\ipykernel_15652\1583950878.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["self_employed"] = df["self_employed"].replace("Yes", 1)
# ...

# %% [markdown]
# ### Correlation Analysis

# %%
# Define a custom colormap
colors = ['#7ae7c7', '#51a48c', 'white', '#176e55', '#14453d']
my_cmap = LinearSegmentedColormap.from_list('custom_map', colors, N=256)


correlation_matrix = df.select_dtypes(include=['number']).corr()

mask = np.zeros_like(correlation_matrix)
mask[np.triu_indices_from(mask, k=1)] = True

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, mask=mask, cmap=my_cmap, annot=True, center=0, fmt='.2f', linewidths=2)
plt.title('Correlation Matrix', fontsize=14)
plt.show()

# %% [markdown]
# Inference:
#
# Looking at the heatmap, we can see that there are some pairs of variables that have high correlations (>= 8.5), for instance:
#
# -   income_annum and loan_amount
# -   income_annum and luxury_assets_value
# -   income_annum and bank_asset_value
# -   loan_amount and luxury_assets_value
#
# These high correlations indicate that these variables move closely together, implying a degree of multicollinearity.

# %%
#dropping columns having 0 correlation with loan_status
df = df.drop(columns=["education", "self_employed"])

# %%
#histogram plotting
df.hist(figsize=(15, 15), bins=20, color='teal')
# Out:
# array([[<Axes: title={'center': 'no_of_dependents'}>,
#         <Axes: title={'center': 'income_annum'}>,
#         <Axes: title={'center': 'loan_amount'}>],
#        [<Axes: title={'center': 'cibil_score'}>,
#         <Axes: title={'center': 'residential_assets_value'}>,
#         <Axes: title={'center': 'commercial_assets_value'}>],
#        [<Axes: title={'center': 'luxury_assets_value'}>,
#         <Axes: title={'center': 'bank_asset_value'}>,
#         <Axes: title={'center': 'loan_status'}>],
#        [<Axes: title={'center': 'scaled_loan_term'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
#class imbalance solution (to be done by dhruv)
#smote analysis

# %% [markdown]
# #### Fairly balanced classes are observed in all features.

# %%
X = df
X = X.drop(columns=['loan_status'])
y = df['loan_status'].copy()

# %%
#train test splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2)

# %%
X_train.to_csv('X_train.csv', index=False)
X_test.to_csv('X_test.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_test.to_csv('y_test.csv', index=False)
